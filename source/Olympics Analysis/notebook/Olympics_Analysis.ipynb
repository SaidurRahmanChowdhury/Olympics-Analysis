# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('athlete_events.csv')
region_df=pd.read_csv('noc_regions.csv')

# %%
df.sample(5)
# Out:
#             ID                                          Name Sex   Age  \
# 214088  107496                  Gerald Click "Gerry" Schreck   M  29.0
# 249647  125010  Patricia Jean "Patty" van Wolvelaere-Johnson   F  22.0
# 112583   57021                               Toshiaki Kamata   M  24.0
# 183054   91998                       George Herbert Patching   M  25.0
# 46784    24124                                 Ferenc Csipes   M  23.0
#
#         Height  Weight           Team  NOC        Games  Year  Season  \
# 214088   175.0    77.0  United States  USA  1968 Summer  1968  Summer
# 249647   170.0    60.0  United States  USA  1972 Summer  1972  Summer
# 112583   168.0    55.0          Japan  JPN  1976 Summer  1976  Summer
# 183054   184.0    77.0   South Africa  RSA  1912 Summer  1912  Summer
# 46784    183.0    90.0        Hungary  HUN  1988 Summer  1988  Summer
#
#                City      Sport                                       Event  \
# 214088  Mexico City    Sailing         Sailing Mixed Three Person Keelboat
# 249647       Munich  Athletics        Athletics Women's 100 metres Hurdles
# 112583     Montreal  Athletics                Athletics Men's 5,000 metres
# 183054    Stockholm  Athletics                  Athletics Men's 100 metres
# 46784         Seoul   Canoeing  Canoeing Men's Kayak Singles, 1,000 metres
#
#        Medal
# 214088  Gold
# 249647   NaN
# 112583   NaN
# 183054   NaN
# 46784    NaN

# %%
df.shape
# Out:
# (271116, 15)

# %%
df=df[df['Season']=='Summer']

# %%
df.shape
# Out:
# (222552, 15)

# %%
region_df.sample(5)
# Out:
#      NOC                            region                notes
# 160  PLW                             Palau                  NaN
# 44   COD  Democratic Republic of the Congo                  NaN
# 110  KOS                            Kosovo                  NaN
# 29   BRA                            Brazil                  NaN
# 6    ANT                           Antigua  Antigua and Barbuda

# %%
df=df.merge(region_df,on='NOC',how='left')

# %%
df.tail()
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 222547  135565      Fernando scar Zylberberg   M  27.0   168.0    76.0
# 222548  135566    James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 222549  135567  Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 222550  135567  Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 222551  135568        Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
#                  Team  NOC        Games  Year  Season            City  \
# 222547      Argentina  ARG  2004 Summer  2004  Summer          Athina
# 222548  United States  USA  1972 Summer  1972  Summer          Munich
# 222549         Russia  RUS  2000 Summer  2000  Summer          Sydney
# 222550         Russia  RUS  2004 Summer  2004  Summer          Athina
# 222551        Belarus  BLR  2016 Summer  2016  Summer  Rio de Janeiro
#
#              Sport                                   Event Medal     region  \
# 222547      Hockey                     Hockey Men's Hockey   NaN  Argentina
# 222548    Football                 Football Men's Football   NaN        USA
# 222549      Rowing  Rowing Men's Lightweight Coxless Fours   NaN     Russia
# 222550      Rowing  Rowing Men's Lightweight Coxless Fours   NaN     Russia
# 222551  Basketball           Basketball Women's Basketball   NaN    Belarus
#
#        notes
# 222547   NaN
# 222548   NaN
# 222549   NaN
# 222550   NaN
# 222551   NaN

# %%
df['region'].unique()
# Out:
# 206
